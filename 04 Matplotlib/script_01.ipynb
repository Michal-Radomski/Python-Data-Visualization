# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([1,2,3,4])
y = np.array([10,20,30,40])

plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y, color="r")
plt.show()

# %%
x=np.arange(1,11)
y=np.exp(x) # e^x
# print(x,y)
plt.plot(x,y)
plt.show()
